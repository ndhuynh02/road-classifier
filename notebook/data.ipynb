# %%
# %cd ..
# Out:
# /work/hpc/hayade/road-classifier

# %%
import glob
from matplotlib import pyplot as plt

# %%
from src.data.road import Road
from src.data.transform_road import TransformRoad

from src.utils import denormalize_image, denormalize_batch

# %%
data = Road(train=True)

# %%
data.labels_map
# Out:
# {'dry_asphalt': 0, 'dry_gravel': 1, 'ice': 2, 'snow': 3}

# %%
sample = data[0]

# %%
image, label = sample

# %%
image.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 image.shape
#
# NameError: name 'image' is not defined

# %%
plt.imshow(sample[0])

# %%
transform_data = TransformRoad(data)

# %%
image, label = transform_data[0]

# %%
plt.imshow(image.permute(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(denormalize_image(image).permute(1, 2, 0))
